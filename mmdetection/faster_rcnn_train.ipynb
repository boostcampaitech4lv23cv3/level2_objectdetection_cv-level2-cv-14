# %%
# 모듈 import

from mmcv import Config
from mmdet.datasets import build_dataset
from mmdet.models import build_detector
from mmdet.apis import train_detector
from mmdet.datasets import (build_dataloader, build_dataset,
                            replace_ImageToTensor)
from mmdet.utils import get_device
# Out:
# /opt/conda/envs/detection/lib/python3.7/site-packages/mmcv/__init__.py:21: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   'On January 1, 2023, MMCV will release v2.0.0, in which it will remove '

# %%
classes = ("General trash", "Paper", "Paper pack", "Metal", "Glass", 
           "Plastic", "Styrofoam", "Plastic bag", "Battery", "Clothing")

# config file 들고오기
cfg = Config.fromfile('./configs/faster_rcnn/faster_rcnn_r50_fpn_1x_coco.py')

root='../../dataset/'

# dataset config 수정
cfg.data.train.classes = classes
cfg.data.train.img_prefix = root
cfg.data.train.ann_file = root + 'train.json' # train json 정보
cfg.data.train.pipeline[2]['img_scale'] = (512,512) # Resize

cfg.data.test.classes = classes
cfg.data.test.img_prefix = root
cfg.data.test.ann_file = root + 'test.json' # test json 정보
cfg.data.test.pipeline[1]['img_scale'] = (512,512) # Resize

cfg.data.samples_per_gpu = 4

cfg.seed = 2022
cfg.gpu_ids = [0]
cfg.work_dir = './work_dirs/faster_rcnn_r50_fpn_1x_trash'

cfg.model.roi_head.bbox_head.num_classes = 10

cfg.optimizer_config.grad_clip = dict(max_norm=35, norm_type=2)
cfg.checkpoint_config = dict(max_keep_ckpts=3, interval=1)
cfg.device = get_device()

# setup wandb

cfg.log_config.hooks = [
    dict(type='TextLoggerHook'),
    dict(type='MMDetWandbHook',
         init_kwargs={
    'project': 'Object Detection',
    'entity': 'juyounghong',
    'config': {'lr': 1e-4, 'batch_size':16},
    'tags': ['resnet50', 'sgd'] 
},
         interval=10,
         log_checkpoint=True,
         log_checkpoint_metadata=True,
         num_eval_images=100,
         bbox_score_thr=0.5)]

# %%
# build_dataset
datasets = [build_dataset(cfg.data.train)]
# Out:
# loading annotations into memory...
# Done (t=0.21s)
# creating index...
# index created!

# %%
# dataset 확인
datasets[0]
# Out:
# CocoDataset Train dataset with number of images 4883, and instance counts:
# +-------------------+-------+---------------+-------+-----------------+-------+-------------+-------+--------------+-------+
# | category          | count | category      | count | category        | count | category    | count | category     | count |
# +-------------------+-------+---------------+-------+-----------------+-------+-------------+-------+--------------+-------+
# | 0 [General trash] | 3965  | 1 [Paper]     | 6352  | 2 [Paper pack]  | 897   | 3 [Metal]   | 936   | 4 [Glass]    | 982   |
# | 5 [Plastic]       | 2943  | 6 [Styrofoam] | 1263  | 7 [Plastic bag] | 5178  | 8 [Battery] | 159   | 9 [Clothing] | 468   |
# +-------------------+-------+---------------+-------+-----------------+-------+-------------+-------+--------------+-------+

# %%
# 모델 build 및 pretrained network 불러오기
model = build_detector(cfg.model)
model.init_weights()
# Out:
# 2022-11-20 14:07:18,652 - mmdet - INFO - load checkpoint from http path: https://github.com/SwinTransformer/storage/releases/download/v1.0.0/swin_tiny_patch4_window7_224.pth
# Downloading: "https://github.com/SwinTransformer/storage/releases/download/v1.0.0/swin_tiny_patch4_window7_224.pth" to /opt/ml/.cache/torch/hub/checkpoints/swin_tiny_patch4_window7_224.pth
#   0%|          | 0.00/109M [00:00<?, ?B/s]
# 2022-11-20 14:07:32,973 - mmdet - INFO - initialize FPN with init_cfg {'type': 'Xavier', 'layer': 'Conv2d', 'distribution': 'uniform'}
# 2022-11-20 14:07:32,996 - mmdet - INFO - initialize RPNHead with init_cfg {'type': 'Normal', 'layer': 'Conv2d', 'std': 0.01}
# 2022-11-20 14:07:33,005 - mmdet - INFO - initialize Shared2FCBBoxHead with init_cfg [{'type': 'Normal', 'std': 0.01, 'override': {'name': 'fc_cls'}}, {'type': 'Normal', 'std': 0.001, 'override': {'name': 'fc_reg'}}, {'type': 'Xavier', 'distribution': 'uniform', 'override': [{'name': 'shared_fcs'}, {'name': 'cls_fcs'}, {'name': 'reg_fcs'}]}]
# 2022-11-20 14:07:33,114 - mmcv - INFO -
# backbone.patch_embed.projection.weight - torch.Size([96, 3, 4, 4]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,115 - mmcv - INFO -
# backbone.patch_embed.projection.bias - torch.Size([96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,115 - mmcv - INFO -
# backbone.patch_embed.norm.weight - torch.Size([96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,119 - mmcv - INFO -
# backbone.patch_embed.norm.bias - torch.Size([96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,121 - mmcv - INFO -
# backbone.stages.0.blocks.0.norm1.weight - torch.Size([96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,126 - mmcv - INFO -
# backbone.stages.0.blocks.0.norm1.bias - torch.Size([96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,127 - mmcv - INFO -
# backbone.stages.0.blocks.0.attn.w_msa.relative_position_bias_table - torch.Size([169, 3]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,131 - mmcv - INFO -
# backbone.stages.0.blocks.0.attn.w_msa.qkv.weight - torch.Size([288, 96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,131 - mmcv - INFO -
# backbone.stages.0.blocks.0.attn.w_msa.qkv.bias - torch.Size([288]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,135 - mmcv - INFO -
# backbone.stages.0.blocks.0.attn.w_msa.proj.weight - torch.Size([96, 96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,135 - mmcv - INFO -
# backbone.stages.0.blocks.0.attn.w_msa.proj.bias - torch.Size([96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,136 - mmcv - INFO -
# backbone.stages.0.blocks.0.norm2.weight - torch.Size([96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,141 - mmcv - INFO -
# backbone.stages.0.blocks.0.norm2.bias - torch.Size([96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,142 - mmcv - INFO -
# backbone.stages.0.blocks.0.ffn.layers.0.0.weight - torch.Size([384, 96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,143 - mmcv - INFO -
# backbone.stages.0.blocks.0.ffn.layers.0.0.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,144 - mmcv - INFO -
# backbone.stages.0.blocks.0.ffn.layers.1.weight - torch.Size([96, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,144 - mmcv - INFO -
# backbone.stages.0.blocks.0.ffn.layers.1.bias - torch.Size([96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,145 - mmcv - INFO -
# backbone.stages.0.blocks.1.norm1.weight - torch.Size([96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,145 - mmcv - INFO -
# backbone.stages.0.blocks.1.norm1.bias - torch.Size([96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,146 - mmcv - INFO -
# backbone.stages.0.blocks.1.attn.w_msa.relative_position_bias_table - torch.Size([169, 3]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,147 - mmcv - INFO -
# backbone.stages.0.blocks.1.attn.w_msa.qkv.weight - torch.Size([288, 96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,147 - mmcv - INFO -
# backbone.stages.0.blocks.1.attn.w_msa.qkv.bias - torch.Size([288]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,148 - mmcv - INFO -
# backbone.stages.0.blocks.1.attn.w_msa.proj.weight - torch.Size([96, 96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,148 - mmcv - INFO -
# backbone.stages.0.blocks.1.attn.w_msa.proj.bias - torch.Size([96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,149 - mmcv - INFO -
# backbone.stages.0.blocks.1.norm2.weight - torch.Size([96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,150 - mmcv - INFO -
# backbone.stages.0.blocks.1.norm2.bias - torch.Size([96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,151 - mmcv - INFO -
# backbone.stages.0.blocks.1.ffn.layers.0.0.weight - torch.Size([384, 96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,151 - mmcv - INFO -
# backbone.stages.0.blocks.1.ffn.layers.0.0.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,152 - mmcv - INFO -
# backbone.stages.0.blocks.1.ffn.layers.1.weight - torch.Size([96, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,153 - mmcv - INFO -
# backbone.stages.0.blocks.1.ffn.layers.1.bias - torch.Size([96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,153 - mmcv - INFO -
# backbone.stages.0.downsample.norm.weight - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,154 - mmcv - INFO -
# backbone.stages.0.downsample.norm.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,155 - mmcv - INFO -
# backbone.stages.0.downsample.reduction.weight - torch.Size([192, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,155 - mmcv - INFO -
# backbone.stages.1.blocks.0.norm1.weight - torch.Size([192]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,156 - mmcv - INFO -
# backbone.stages.1.blocks.0.norm1.bias - torch.Size([192]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,157 - mmcv - INFO -
# backbone.stages.1.blocks.0.attn.w_msa.relative_position_bias_table - torch.Size([169, 6]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,157 - mmcv - INFO -
# backbone.stages.1.blocks.0.attn.w_msa.qkv.weight - torch.Size([576, 192]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,158 - mmcv - INFO -
# backbone.stages.1.blocks.0.attn.w_msa.qkv.bias - torch.Size([576]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,159 - mmcv - INFO -
# backbone.stages.1.blocks.0.attn.w_msa.proj.weight - torch.Size([192, 192]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,159 - mmcv - INFO -
# backbone.stages.1.blocks.0.attn.w_msa.proj.bias - torch.Size([192]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,160 - mmcv - INFO -
# backbone.stages.1.blocks.0.norm2.weight - torch.Size([192]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,161 - mmcv - INFO -
# backbone.stages.1.blocks.0.norm2.bias - torch.Size([192]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,161 - mmcv - INFO -
# backbone.stages.1.blocks.0.ffn.layers.0.0.weight - torch.Size([768, 192]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,162 - mmcv - INFO -
# backbone.stages.1.blocks.0.ffn.layers.0.0.bias - torch.Size([768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,163 - mmcv - INFO -
# backbone.stages.1.blocks.0.ffn.layers.1.weight - torch.Size([192, 768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,164 - mmcv - INFO -
# backbone.stages.1.blocks.0.ffn.layers.1.bias - torch.Size([192]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,164 - mmcv - INFO -
# backbone.stages.1.blocks.1.norm1.weight - torch.Size([192]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,165 - mmcv - INFO -
# backbone.stages.1.blocks.1.norm1.bias - torch.Size([192]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,166 - mmcv - INFO -
# backbone.stages.1.blocks.1.attn.w_msa.relative_position_bias_table - torch.Size([169, 6]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,166 - mmcv - INFO -
# backbone.stages.1.blocks.1.attn.w_msa.qkv.weight - torch.Size([576, 192]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,167 - mmcv - INFO -
# backbone.stages.1.blocks.1.attn.w_msa.qkv.bias - torch.Size([576]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,168 - mmcv - INFO -
# backbone.stages.1.blocks.1.attn.w_msa.proj.weight - torch.Size([192, 192]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,168 - mmcv - INFO -
# backbone.stages.1.blocks.1.attn.w_msa.proj.bias - torch.Size([192]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,169 - mmcv - INFO -
# backbone.stages.1.blocks.1.norm2.weight - torch.Size([192]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,170 - mmcv - INFO -
# backbone.stages.1.blocks.1.norm2.bias - torch.Size([192]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,170 - mmcv - INFO -
# backbone.stages.1.blocks.1.ffn.layers.0.0.weight - torch.Size([768, 192]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,171 - mmcv - INFO -
# backbone.stages.1.blocks.1.ffn.layers.0.0.bias - torch.Size([768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,172 - mmcv - INFO -
# backbone.stages.1.blocks.1.ffn.layers.1.weight - torch.Size([192, 768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,172 - mmcv - INFO -
# backbone.stages.1.blocks.1.ffn.layers.1.bias - torch.Size([192]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,173 - mmcv - INFO -
# backbone.stages.1.downsample.norm.weight - torch.Size([768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,174 - mmcv - INFO -
# backbone.stages.1.downsample.norm.bias - torch.Size([768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,174 - mmcv - INFO -
# backbone.stages.1.downsample.reduction.weight - torch.Size([384, 768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,175 - mmcv - INFO -
# backbone.stages.2.blocks.0.norm1.weight - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,176 - mmcv - INFO -
# backbone.stages.2.blocks.0.norm1.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,176 - mmcv - INFO -
# backbone.stages.2.blocks.0.attn.w_msa.relative_position_bias_table - torch.Size([169, 12]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,177 - mmcv - INFO -
# backbone.stages.2.blocks.0.attn.w_msa.qkv.weight - torch.Size([1152, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,178 - mmcv - INFO -
# backbone.stages.2.blocks.0.attn.w_msa.qkv.bias - torch.Size([1152]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,178 - mmcv - INFO -
# backbone.stages.2.blocks.0.attn.w_msa.proj.weight - torch.Size([384, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,179 - mmcv - INFO -
# backbone.stages.2.blocks.0.attn.w_msa.proj.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,180 - mmcv - INFO -
# backbone.stages.2.blocks.0.norm2.weight - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,181 - mmcv - INFO -
# backbone.stages.2.blocks.0.norm2.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,181 - mmcv - INFO -
# backbone.stages.2.blocks.0.ffn.layers.0.0.weight - torch.Size([1536, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,182 - mmcv - INFO -
# backbone.stages.2.blocks.0.ffn.layers.0.0.bias - torch.Size([1536]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,183 - mmcv - INFO -
# backbone.stages.2.blocks.0.ffn.layers.1.weight - torch.Size([384, 1536]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,184 - mmcv - INFO -
# backbone.stages.2.blocks.0.ffn.layers.1.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,185 - mmcv - INFO -
# backbone.stages.2.blocks.1.norm1.weight - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,186 - mmcv - INFO -
# backbone.stages.2.blocks.1.norm1.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,186 - mmcv - INFO -
# backbone.stages.2.blocks.1.attn.w_msa.relative_position_bias_table - torch.Size([169, 12]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,187 - mmcv - INFO -
# backbone.stages.2.blocks.1.attn.w_msa.qkv.weight - torch.Size([1152, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,188 - mmcv - INFO -
# backbone.stages.2.blocks.1.attn.w_msa.qkv.bias - torch.Size([1152]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,189 - mmcv - INFO -
# backbone.stages.2.blocks.1.attn.w_msa.proj.weight - torch.Size([384, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,190 - mmcv - INFO -
# backbone.stages.2.blocks.1.attn.w_msa.proj.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,191 - mmcv - INFO -
# backbone.stages.2.blocks.1.norm2.weight - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,192 - mmcv - INFO -
# backbone.stages.2.blocks.1.norm2.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,193 - mmcv - INFO -
# backbone.stages.2.blocks.1.ffn.layers.0.0.weight - torch.Size([1536, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,195 - mmcv - INFO -
# backbone.stages.2.blocks.1.ffn.layers.0.0.bias - torch.Size([1536]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,196 - mmcv - INFO -
# backbone.stages.2.blocks.1.ffn.layers.1.weight - torch.Size([384, 1536]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,197 - mmcv - INFO -
# backbone.stages.2.blocks.1.ffn.layers.1.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,198 - mmcv - INFO -
# backbone.stages.2.blocks.2.norm1.weight - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,198 - mmcv - INFO -
# backbone.stages.2.blocks.2.norm1.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,199 - mmcv - INFO -
# backbone.stages.2.blocks.2.attn.w_msa.relative_position_bias_table - torch.Size([169, 12]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,200 - mmcv - INFO -
# backbone.stages.2.blocks.2.attn.w_msa.qkv.weight - torch.Size([1152, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,201 - mmcv - INFO -
# backbone.stages.2.blocks.2.attn.w_msa.qkv.bias - torch.Size([1152]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,202 - mmcv - INFO -
# backbone.stages.2.blocks.2.attn.w_msa.proj.weight - torch.Size([384, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,203 - mmcv - INFO -
# backbone.stages.2.blocks.2.attn.w_msa.proj.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,204 - mmcv - INFO -
# backbone.stages.2.blocks.2.norm2.weight - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,205 - mmcv - INFO -
# backbone.stages.2.blocks.2.norm2.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,206 - mmcv - INFO -
# backbone.stages.2.blocks.2.ffn.layers.0.0.weight - torch.Size([1536, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,206 - mmcv - INFO -
# backbone.stages.2.blocks.2.ffn.layers.0.0.bias - torch.Size([1536]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,207 - mmcv - INFO -
# backbone.stages.2.blocks.2.ffn.layers.1.weight - torch.Size([384, 1536]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,208 - mmcv - INFO -
# backbone.stages.2.blocks.2.ffn.layers.1.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,209 - mmcv - INFO -
# backbone.stages.2.blocks.3.norm1.weight - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,210 - mmcv - INFO -
# backbone.stages.2.blocks.3.norm1.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,211 - mmcv - INFO -
# backbone.stages.2.blocks.3.attn.w_msa.relative_position_bias_table - torch.Size([169, 12]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,212 - mmcv - INFO -
# backbone.stages.2.blocks.3.attn.w_msa.qkv.weight - torch.Size([1152, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,213 - mmcv - INFO -
# backbone.stages.2.blocks.3.attn.w_msa.qkv.bias - torch.Size([1152]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,214 - mmcv - INFO -
# backbone.stages.2.blocks.3.attn.w_msa.proj.weight - torch.Size([384, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,215 - mmcv - INFO -
# backbone.stages.2.blocks.3.attn.w_msa.proj.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,215 - mmcv - INFO -
# backbone.stages.2.blocks.3.norm2.weight - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,216 - mmcv - INFO -
# backbone.stages.2.blocks.3.norm2.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,217 - mmcv - INFO -
# backbone.stages.2.blocks.3.ffn.layers.0.0.weight - torch.Size([1536, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,218 - mmcv - INFO -
# backbone.stages.2.blocks.3.ffn.layers.0.0.bias - torch.Size([1536]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,219 - mmcv - INFO -
# backbone.stages.2.blocks.3.ffn.layers.1.weight - torch.Size([384, 1536]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,220 - mmcv - INFO -
# backbone.stages.2.blocks.3.ffn.layers.1.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,221 - mmcv - INFO -
# backbone.stages.2.blocks.4.norm1.weight - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,222 - mmcv - INFO -
# backbone.stages.2.blocks.4.norm1.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,223 - mmcv - INFO -
# backbone.stages.2.blocks.4.attn.w_msa.relative_position_bias_table - torch.Size([169, 12]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,224 - mmcv - INFO -
# backbone.stages.2.blocks.4.attn.w_msa.qkv.weight - torch.Size([1152, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,225 - mmcv - INFO -
# backbone.stages.2.blocks.4.attn.w_msa.qkv.bias - torch.Size([1152]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,226 - mmcv - INFO -
# backbone.stages.2.blocks.4.attn.w_msa.proj.weight - torch.Size([384, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,227 - mmcv - INFO -
# backbone.stages.2.blocks.4.attn.w_msa.proj.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,228 - mmcv - INFO -
# backbone.stages.2.blocks.4.norm2.weight - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,229 - mmcv - INFO -
# backbone.stages.2.blocks.4.norm2.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,230 - mmcv - INFO -
# backbone.stages.2.blocks.4.ffn.layers.0.0.weight - torch.Size([1536, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,231 - mmcv - INFO -
# backbone.stages.2.blocks.4.ffn.layers.0.0.bias - torch.Size([1536]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,231 - mmcv - INFO -
# backbone.stages.2.blocks.4.ffn.layers.1.weight - torch.Size([384, 1536]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,232 - mmcv - INFO -
# backbone.stages.2.blocks.4.ffn.layers.1.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,233 - mmcv - INFO -
# backbone.stages.2.blocks.5.norm1.weight - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,234 - mmcv - INFO -
# backbone.stages.2.blocks.5.norm1.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,235 - mmcv - INFO -
# backbone.stages.2.blocks.5.attn.w_msa.relative_position_bias_table - torch.Size([169, 12]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,236 - mmcv - INFO -
# backbone.stages.2.blocks.5.attn.w_msa.qkv.weight - torch.Size([1152, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,237 - mmcv - INFO -
# backbone.stages.2.blocks.5.attn.w_msa.qkv.bias - torch.Size([1152]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,238 - mmcv - INFO -
# backbone.stages.2.blocks.5.attn.w_msa.proj.weight - torch.Size([384, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,239 - mmcv - INFO -
# backbone.stages.2.blocks.5.attn.w_msa.proj.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,240 - mmcv - INFO -
# backbone.stages.2.blocks.5.norm2.weight - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,241 - mmcv - INFO -
# backbone.stages.2.blocks.5.norm2.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,242 - mmcv - INFO -
# backbone.stages.2.blocks.5.ffn.layers.0.0.weight - torch.Size([1536, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,243 - mmcv - INFO -
# backbone.stages.2.blocks.5.ffn.layers.0.0.bias - torch.Size([1536]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,244 - mmcv - INFO -
# backbone.stages.2.blocks.5.ffn.layers.1.weight - torch.Size([384, 1536]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,245 - mmcv - INFO -
# backbone.stages.2.blocks.5.ffn.layers.1.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,246 - mmcv - INFO -
# backbone.stages.2.downsample.norm.weight - torch.Size([1536]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,246 - mmcv - INFO -
# backbone.stages.2.downsample.norm.bias - torch.Size([1536]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,248 - mmcv - INFO -
# backbone.stages.2.downsample.reduction.weight - torch.Size([768, 1536]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,249 - mmcv - INFO -
# backbone.stages.3.blocks.0.norm1.weight - torch.Size([768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,251 - mmcv - INFO -
# backbone.stages.3.blocks.0.norm1.bias - torch.Size([768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,252 - mmcv - INFO -
# backbone.stages.3.blocks.0.attn.w_msa.relative_position_bias_table - torch.Size([169, 24]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,253 - mmcv - INFO -
# backbone.stages.3.blocks.0.attn.w_msa.qkv.weight - torch.Size([2304, 768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,253 - mmcv - INFO -
# backbone.stages.3.blocks.0.attn.w_msa.qkv.bias - torch.Size([2304]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,254 - mmcv - INFO -
# backbone.stages.3.blocks.0.attn.w_msa.proj.weight - torch.Size([768, 768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,255 - mmcv - INFO -
# backbone.stages.3.blocks.0.attn.w_msa.proj.bias - torch.Size([768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,256 - mmcv - INFO -
# backbone.stages.3.blocks.0.norm2.weight - torch.Size([768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,257 - mmcv - INFO -
# backbone.stages.3.blocks.0.norm2.bias - torch.Size([768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,258 - mmcv - INFO -
# backbone.stages.3.blocks.0.ffn.layers.0.0.weight - torch.Size([3072, 768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,259 - mmcv - INFO -
# backbone.stages.3.blocks.0.ffn.layers.0.0.bias - torch.Size([3072]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,260 - mmcv - INFO -
# backbone.stages.3.blocks.0.ffn.layers.1.weight - torch.Size([768, 3072]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,261 - mmcv - INFO -
# backbone.stages.3.blocks.0.ffn.layers.1.bias - torch.Size([768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,262 - mmcv - INFO -
# backbone.stages.3.blocks.1.norm1.weight - torch.Size([768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,263 - mmcv - INFO -
# backbone.stages.3.blocks.1.norm1.bias - torch.Size([768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,264 - mmcv - INFO -
# backbone.stages.3.blocks.1.attn.w_msa.relative_position_bias_table - torch.Size([169, 24]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,265 - mmcv - INFO -
# backbone.stages.3.blocks.1.attn.w_msa.qkv.weight - torch.Size([2304, 768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,266 - mmcv - INFO -
# backbone.stages.3.blocks.1.attn.w_msa.qkv.bias - torch.Size([2304]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,267 - mmcv - INFO -
# backbone.stages.3.blocks.1.attn.w_msa.proj.weight - torch.Size([768, 768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,268 - mmcv - INFO -
# backbone.stages.3.blocks.1.attn.w_msa.proj.bias - torch.Size([768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,269 - mmcv - INFO -
# backbone.stages.3.blocks.1.norm2.weight - torch.Size([768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,270 - mmcv - INFO -
# backbone.stages.3.blocks.1.norm2.bias - torch.Size([768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,270 - mmcv - INFO -
# backbone.stages.3.blocks.1.ffn.layers.0.0.weight - torch.Size([3072, 768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,271 - mmcv - INFO -
# backbone.stages.3.blocks.1.ffn.layers.0.0.bias - torch.Size([3072]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,272 - mmcv - INFO -
# backbone.stages.3.blocks.1.ffn.layers.1.weight - torch.Size([768, 3072]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,273 - mmcv - INFO -
# backbone.stages.3.blocks.1.ffn.layers.1.bias - torch.Size([768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-11-20 14:07:33,274 - mmcv - INFO -
# backbone.norm0.weight - torch.Size([96]):
# The value is the same before and after calling `init_weights` of MaskRCNN
#
# 2022-11-20 14:07:33,275 - mmcv - INFO -
# backbone.norm0.bias - torch.Size([96]):
# The value is the same before and after calling `init_weights` of MaskRCNN
#
# 2022-11-20 14:07:33,276 - mmcv - INFO -
# backbone.norm1.weight - torch.Size([192]):
# The value is the same before and after calling `init_weights` of MaskRCNN
#
# 2022-11-20 14:07:33,277 - mmcv - INFO -
# backbone.norm1.bias - torch.Size([192]):
# The value is the same before and after calling `init_weights` of MaskRCNN
#
# 2022-11-20 14:07:33,278 - mmcv - INFO -
# backbone.norm2.weight - torch.Size([384]):
# The value is the same before and after calling `init_weights` of MaskRCNN
#
# 2022-11-20 14:07:33,279 - mmcv - INFO -
# backbone.norm2.bias - torch.Size([384]):
# The value is the same before and after calling `init_weights` of MaskRCNN
#
# 2022-11-20 14:07:33,280 - mmcv - INFO -
# backbone.norm3.weight - torch.Size([768]):
# The value is the same before and after calling `init_weights` of MaskRCNN
#
# 2022-11-20 14:07:33,281 - mmcv - INFO -
# backbone.norm3.bias - torch.Size([768]):
# The value is the same before and after calling `init_weights` of MaskRCNN
#
# 2022-11-20 14:07:33,282 - mmcv - INFO -
# neck.lateral_convs.0.conv.weight - torch.Size([256, 96, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-11-20 14:07:33,284 - mmcv - INFO -
# neck.lateral_convs.0.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of MaskRCNN
#
# 2022-11-20 14:07:33,285 - mmcv - INFO -
# neck.lateral_convs.1.conv.weight - torch.Size([256, 192, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-11-20 14:07:33,287 - mmcv - INFO -
# neck.lateral_convs.1.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of MaskRCNN
#
# 2022-11-20 14:07:33,288 - mmcv - INFO -
# neck.lateral_convs.2.conv.weight - torch.Size([256, 384, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-11-20 14:07:33,290 - mmcv - INFO -
# neck.lateral_convs.2.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of MaskRCNN
#
# 2022-11-20 14:07:33,291 - mmcv - INFO -
# neck.lateral_convs.3.conv.weight - torch.Size([256, 768, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-11-20 14:07:33,292 - mmcv - INFO -
# neck.lateral_convs.3.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of MaskRCNN
#
# 2022-11-20 14:07:33,293 - mmcv - INFO -
# neck.fpn_convs.0.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-11-20 14:07:33,294 - mmcv - INFO -
# neck.fpn_convs.0.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of MaskRCNN
#
# 2022-11-20 14:07:33,295 - mmcv - INFO -
# neck.fpn_convs.1.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-11-20 14:07:33,296 - mmcv - INFO -
# neck.fpn_convs.1.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of MaskRCNN
#
# 2022-11-20 14:07:33,296 - mmcv - INFO -
# neck.fpn_convs.2.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-11-20 14:07:33,297 - mmcv - INFO -
# neck.fpn_convs.2.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of MaskRCNN
#
# 2022-11-20 14:07:33,298 - mmcv - INFO -
# neck.fpn_convs.3.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-11-20 14:07:33,299 - mmcv - INFO -
# neck.fpn_convs.3.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of MaskRCNN
#
# 2022-11-20 14:07:33,299 - mmcv - INFO -
# rpn_head.rpn_conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-11-20 14:07:33,300 - mmcv - INFO -
# rpn_head.rpn_conv.bias - torch.Size([256]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-11-20 14:07:33,301 - mmcv - INFO -
# rpn_head.rpn_cls.weight - torch.Size([3, 256, 1, 1]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-11-20 14:07:33,301 - mmcv - INFO -
# rpn_head.rpn_cls.bias - torch.Size([3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-11-20 14:07:33,302 - mmcv - INFO -
# rpn_head.rpn_reg.weight - torch.Size([12, 256, 1, 1]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-11-20 14:07:33,303 - mmcv - INFO -
# rpn_head.rpn_reg.bias - torch.Size([12]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-11-20 14:07:33,303 - mmcv - INFO -
# roi_head.bbox_head.fc_cls.weight - torch.Size([11, 1024]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-11-20 14:07:33,304 - mmcv - INFO -
# roi_head.bbox_head.fc_cls.bias - torch.Size([11]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-11-20 14:07:33,305 - mmcv - INFO -
# roi_head.bbox_head.fc_reg.weight - torch.Size([40, 1024]):
# NormalInit: mean=0, std=0.001, bias=0
#
# 2022-11-20 14:07:33,305 - mmcv - INFO -
# roi_head.bbox_head.fc_reg.bias - torch.Size([40]):
# NormalInit: mean=0, std=0.001, bias=0
#
# 2022-11-20 14:07:33,306 - mmcv - INFO -
# roi_head.bbox_head.shared_fcs.0.weight - torch.Size([1024, 12544]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-11-20 14:07:33,307 - mmcv - INFO -
# roi_head.bbox_head.shared_fcs.0.bias - torch.Size([1024]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-11-20 14:07:33,307 - mmcv - INFO -
# roi_head.bbox_head.shared_fcs.1.weight - torch.Size([1024, 1024]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-11-20 14:07:33,308 - mmcv - INFO -
# roi_head.bbox_head.shared_fcs.1.bias - torch.Size([1024]):
# XavierInit: gain=1, distribution=uniform, bias=0

# %%
# 모델 학습
train_detector(model, datasets[0], cfg, distributed=False, validate=False)
# Out:
# 2022-11-20 14:07:36,152 - mmdet - INFO - Automatic scaling of learning rate (LR) has been disabled.
# 2022-11-20 14:07:36,607 - mmdet - INFO - Start running, host: root@36e87c75a3b2, work_dir: /opt/ml/baseline/mmdetection/work_dirs/faster_rcnn_r50_fpn_1x_trash
# 2022-11-20 14:07:36,608 - mmdet - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) CheckpointHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) MMDetWandbHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) NumClassCheckHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) MMDetWandbHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) StepLrUpdaterHook
# (LOW         ) IterTimerHook
#  --------------------
# after_train_iter:
# (ABOVE_NORMAL) OptimizerHook
# (NORMAL      ) CheckpointHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) MMDetWandbHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) CheckpointHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) MMDetWandbHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) NumClassCheckHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) MMDetWandbHook
#  --------------------
# before_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_epoch:
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) MMDetWandbHook
#  --------------------
# after_run:
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) MMDetWandbHook
#  --------------------
# 2022-11-20 14:07:36,609 - mmdet - INFO - workflow: [('train', 1)], max: 12 epochs
# 2022-11-20 14:07:36,611 - mmdet - INFO - Checkpoints will be saved to /opt/ml/baseline/mmdetection/work_dirs/faster_rcnn_r50_fpn_1x_trash by HardDiskBackend.
# wandb: Currently logged in as: juyounghong. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/opt/ml/baseline/mmdetection/wandb/run-20221120_140738-1b4xrz8j</code>
# Syncing run <strong><a href="https://wandb.ai/juyounghong/Object%20Detection/runs/1b4xrz8j" target="_blank">morning-night-4</a></strong> to <a href="https://wandb.ai/juyounghong/Object%20Detection" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# 2022-11-20 14:07:42,955 - mmdet - WARNING - No meta information found in the runner.
# 2022-11-20 14:07:42,956 - mmdet - WARNING - To log evaluation or checkpoint metadata in MMDetWandbHook, `EvalHook` or `DistEvalHook` in mmdet is required, please check whether the validation is enabled.
# 2022-11-20 14:08:02,015 - mmdet - INFO - Epoch [1][50/1221]	lr: 1.978e-03, eta: 1:32:44, time: 0.381, data_time: 0.051, memory: 3749, loss_rpn_cls: 0.3552, loss_rpn_bbox: 0.0448, loss_cls: 0.5285, acc: 90.1250, loss_bbox: 0.1068, loss: 1.0354, grad_norm: 6.7482
# 2022-11-20 14:08:18,571 - mmdet - INFO - Epoch [1][100/1221]	lr: 3.976e-03, eta: 1:26:21, time: 0.331, data_time: 0.006, memory: 3749, loss_rpn_cls: 0.1954, loss_rpn_bbox: 0.0577, loss_cls: 0.3003, acc: 94.5098, loss_bbox: 0.1997, loss: 0.7529, grad_norm: 2.3957
# 2022-11-20 14:08:34,989 - mmdet - INFO - Epoch [1][150/1221]	lr: 5.974e-03, eta: 1:23:49, time: 0.328, data_time: 0.006, memory: 3750, loss_rpn_cls: 0.1667, loss_rpn_bbox: 0.0545, loss_cls: 0.3265, acc: 93.8672, loss_bbox: 0.2265, loss: 0.7743, grad_norm: 2.5047
# 2022-11-20 14:08:51,333 - mmdet - INFO - Epoch [1][200/1221]	lr: 7.972e-03, eta: 1:22:20, time: 0.327, data_time: 0.006, memory: 3750, loss_rpn_cls: 0.1291, loss_rpn_bbox: 0.0458, loss_cls: 0.3266, acc: 93.7646, loss_bbox: 0.2353, loss: 0.7367, grad_norm: 2.3293
# 2022-11-20 14:09:07,850 - mmdet - INFO - Epoch [1][250/1221]	lr: 9.970e-03, eta: 1:21:30, time: 0.330, data_time: 0.007, memory: 3750, loss_rpn_cls: 0.1235, loss_rpn_bbox: 0.0473, loss_cls: 0.3258, acc: 93.4062, loss_bbox: 0.2514, loss: 0.7480, grad_norm: 2.1921
# 2022-11-20 14:09:24,037 - mmdet - INFO - Epoch [1][300/1221]	lr: 1.197e-02, eta: 1:20:35, time: 0.324, data_time: 0.006, memory: 3750, loss_rpn_cls: 0.1334, loss_rpn_bbox: 0.0541, loss_cls: 0.3218, acc: 93.3467, loss_bbox: 0.2495, loss: 0.7588, grad_norm: 2.3775
# 2022-11-20 14:09:40,407 - mmdet - INFO - Epoch [1][350/1221]	lr: 1.397e-02, eta: 1:19:59, time: 0.327, data_time: 0.007, memory: 3750, loss_rpn_cls: 0.
data_time: 0.007, memory: 3750, loss_rpn_cls: 0.0563, loss_rpn_bbox: 0.0399, loss_cls: 0.2598, acc: 92.9824, loss_bbox: 0.2084, loss: 0.5644, grad_norm: 1.6139
# 2022-11-20 14:18:51,872 - mmdet - INFO - Epoch [2][800/1221]	lr: 2.000e-02, eta: 1:08:22, time: 0.325, data_time: 0.007, memory: 3750, loss_rpn_cls: 0.0842, loss_rpn_bbox: 0.0545, loss_cls: 0.3262, acc: 91.3926, loss_bbox: 0.2701, loss: 0.7350, grad_norm: 1.8948
# 2022-11-20 14:19:07,802 - mmdet - INFO - Epoch [2][850/1221]	lr: 2.000e-02, eta: 1:08:04, time: 0.319, data_time: 0.007, memory: 3750, loss_rpn_cls: 0.0739, loss_rpn_bbox: 0.0480, loss_cls: 0.2997, acc: 91.7217, loss_bbox: 0.2606, loss: 0.6823, grad_norm: 1.7440
# 2022-11-20 14:19:24,219 - mmdet - INFO - Epoch [2][900/1221]	lr: 2.000e-02, eta: 1:07:49, time: 0.328, data_time: 0.007, memory: 3750, loss_rpn_cls: 0.0679, loss_rpn_bbox: 0.0417, loss_cls: 0.2819, acc: 92.2207, loss_bbox: 0.2354, loss: 0.6269, grad_norm: 1.7965
# 2022-11-20 14:19:40,734 - mmdet - INFO - Epoch [2][950/1221]	lr: 2.000e-02, eta: 1:07:34, time: 0.330, data_time: 0.007, memory: 3750, loss_rpn_cls: 0.0780, loss_rpn_bbox: 0.0457, loss_cls: 0.3207, acc: 91.6084, loss_bbox: 0.2569, loss: 0.7012, grad_norm: 1.8838
# 2022-11-20 14:19:56,805 - mmdet - INFO - Epoch [2][1000/1221]	lr: 2.000e-02, eta: 1:07:17, time: 0.321, data_time: 0.007, memory: 3750, loss_rpn_cls: 0.0658, loss_rpn_bbox: 0.0435, loss_cls: 0.3446, acc: 90.8145, loss_bbox: 0.2724, loss: 0.7263, grad_norm: 1.8770
# 2022-11-20 14:20:13,169 - mmdet - INFO - Epoch [2][1050/1221]	lr: 2.000e-02, eta: 1:07:02, time: 0.327, data_time: 0.007, memory: 3750, loss_rpn_cls: 0.0826, loss_rpn_bbox: 0.0535, loss_cls: 0.3181, acc: 91.2119, loss_bbox: 0.2686, loss: 0.7228, grad_norm: 1.9563
# 2022-11-20 14:20:29,501 - mmdet - INFO - Epoch [2][1100/1221]	lr: 2.000e-02, eta: 1:06:46, time: 0.327, data_time: 0.007, memory: 3750, loss_rpn_cls: 0.0787, loss_rpn_bbox: 0.0435, loss_cls: 0.2855, acc: 92.3633, loss_bbox: 0.2309, loss: 0.6386, grad_norm: 1.8712
# 2022-11-20 14:20:46,026 - mmdet - INFO - Epoch [2][1150/1221]	lr: 2.000e-02, eta: 1:06:31, time: 0.330, data_time: 0.007, memory: 3750, loss_rpn_cls: 0.0752, loss_rpn_bbox: 0.0514, loss_cls: 0.2990, acc: 91.9199, loss_bbox: 0.2516, loss: 0.6771, grad_norm: 1.7503
# 2022-11-20 14:21:02,437 - mmdet - INFO - Epoch [2][1200/1221]	lr: 2.000e-02, eta: 1:06:16, time: 0.328, data_time: 0.007, memory: 3750, loss_rpn_cls: 0.0714, loss_rpn_bbox: 0.0389, loss_cls: 0.2895, acc: 92.4229, loss_bbox: 0.2255, loss: 0.6253, grad_norm: 1.8219
# 2022-11-20 14:21:09,403 - mmdet - INFO - Saving checkpoint at 2 epochs
# 2022-11-20 14:21:32,491 - mmdet - INFO - Epoch [3][50/1221]	lr: 2.000e-02, eta: 1:05:33, time: 0.382, data_time: 0.052, memory: 3750, loss_rpn_cls: 0.0676, loss_rpn_bbox: 0.0507, loss_cls: 0.2793, acc: 91.9727, loss_bbox: 0.2474, loss: 0.6451, grad_norm: 1.6332
